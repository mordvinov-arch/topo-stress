# %% [markdown]
# # Разведка данных MASTЗагрузка производных датасетов из `data/processed`. Если файлов нет — сначала выполните `python scripts/run_data.py`.

# %%
import syssys.path.insert(0, '../src')import pandas as pdpd.set_option('display.max_columns', None)from topostress.data import load_widewide = load_wide()wide.shape

# %%
wide.head()wide.groupby('Group')[['Cortisol_peak', 'AUCg', 'Slope_logcortisol', 'Anxiety_peak']].mean().round(3)

# %%
wide.groupby(['Exp', 'Group']).size().unstack(fill_value=0)

# %% [markdown]
# Далее: полный анализ запускается `python scripts/run_all.py`.
