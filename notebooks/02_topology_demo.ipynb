# %% [markdown]
# # Демонстрация топологической метрики d~topoНормированная топологическая дивергенция между облаками точек: различие кривых Бетти нулевого порядка.

# %%
import syssys.path.insert(0, '../src')import numpy as npfrom topostress.topology import d_topo_normalizedrng = np.random.default_rng(0)X = rng.standard_normal((100, 5))Y = rng.standard_normal((100, 5)) * 1.5 + 0.5d, t, b1, b2 = d_topo_normalized(X, Y)print('d~topo =', round(d, 4))

# %%
# Структурное отличие: кластер против равномерного облакаcluster = rng.standard_normal((100, 5)) * 0.3spread = rng.uniform(-2, 2, (100, 5))d2, *_ = d_topo_normalized(cluster, spread)print('cluster vs spread: d~topo =', round(d2, 4))

# %% [markdown]
# Реальные данные: различия Stress vs Control (см. `scripts/run_tda.py`).
